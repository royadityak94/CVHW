# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from utils import imread
#from detectBlobs import detectBlobs
from drawBlobs import drawBlobs
import numpy as np
import cv2
from skimage.color import rgb2gray
from scipy.ndimage import gaussian_laplace
from scipy.ndimage.filters import convolve, generic_filter
# %matplotlib inline

# %%
imageName = 'butterfly.jpg'
numBlobsToDraw = 500
imName = imageName.split('.')[0]
datadir = os.path.join('..', 'data', 'blobs')
im = imread(os.path.join(datadir, imageName))
plt.imshow(im, cmap='gray')
# BLOBS - n x 5 array with blob in each row in (x, y, radius, angle, score)
blobs = np.array([im.shape[1]/2, im.shape[0]/2, 100, 1.0])

# %%
import sys
def py_im2double(img):
    original_img = img.astype('float')
    img_min, img_max = np.min(im.ravel()), np.max(im.ravel())
    return (original_img - img_min) / (img_max - img_min)

# def fspecial(shape=(3,3),sigma=0.5):
#     """
#     2D gaussian mask - should give the same result as MATLAB's
#     fspecial('gaussian',[shape],[sigma])
#     """
#     m,n = [(ss-1.)/2. for ss in shape]
#     y,x = np.ogrid[-m:m+1,-n:n+1]
#     h = np.exp( -(x*x + y*y) / (2.*sigma*sigma) )
#     h[ h < np.finfo(h.dtype).eps*h.max() ] = 0
#     sumh = h.sum()
#     if sumh != 0:
#         h /= sumh
#     return h

def fspecial_log(p2, std):
    siz = int((p2-1)/2)
    x = y = np.linspace(-siz, siz, 2*siz+1)
    x, y = np.meshgrid(x, y)
    arg = -(x**2 + y**2) / (2*std**2)
    h = np.exp(arg)
    h[h < sys.float_info.epsilon * h.max()] = 0
    h = h/h.sum() if h.sum() != 0 else h
    h1 = h*(x**2 + y**2 - 2*std**2) / (std**4)
    return h1 - h1.mean()

# %%
processed_im = py_im2double(rgb2gray(im))
sigma = 2 #1.6
k = np.sqrt(2) #initial_scale
scale = 1.2
n_iterations = 10
n = 12 #10-15
threshold = 0.2
h, w = processed_im.shape
scale_space = np.zeros((h, w, n))

# %%
# Build a Laplacian scale space, starting with some initial scale and going for n iterations
for i in range(n):
    sigma_i = np.power(k, i-1) * sigma
    filtered_im = gaussian_laplace(processed_im, sigma=sigma_i) ** 2
    scale_space[:, :, i] = filtered_im

# %%
# # Perform non-maximum suppression in scale space
# max_space = np.zeros((h, w, n))
# suppression_size = 3
# for i in range(n): 
#     R = scale_space[:, :, i]
#     Rmax = generic_filter(R, np.max, footprint=np.ones((3, 3)) )
#     max_space[:, :, i] = Rmax
#     #Rmax[Rmax != R] = 0 #Suppression of Non-max
#     #v = Rmax[Rmax != 0]
#     #x, y = np.nonzero(Rmax)

# %%
max_space = np.zeros((h, w, n))
suppression_size = 3
for i in range(n):
    R = scale_space[:, :, i]
    Rmax = generic_filter(R, np.max, footprint=np.ones((3, 3)) )
    print (np.maximum(i-1, 0), np.minimum(i+1,n))
    print (Rmax[:, np.maximum(i-1, 0):np.minimum(i+1,n)])
    k = np.maximum(Rmax[:, np.maximum(i-1, 0):np.minimum(i+1,n)]) 
    print (k)
    #maxSpace(:,:,max(i-1,1):min(i+1,n)),[],3)
# Out:
# (0, 1)
# [[  5.34279616e-05]
#  [  1.08449884e-04]
#  [  1.27901533e-04]
#  [  1.27901533e-04]
#  [  9.41287786e-06]
#  [  9.41287786e-06]
#  [  2.25702819e-05]
#  [  3.93980650e-05]
#  [  3.93980650e-05]
#  [  3.93980650e-05]
#  [  1.03073782e-05]
#  [  1.36289566e-05]
#  [  1.36289566e-05]
#  [  1.36289566e-05]
#  [  7.80378563e-06]
#  [  4.84588152e-06]
#  [  2.26876509e-05]
#  [  2.26876509e-05]
#  [  2.26876509e-05]
#  [  1.11359394e-05]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-2c7696643ada> in <module>()
#       6     print (np.maximum(i-1, 0), np.minimum(i+1,n))
#       7     print (Rmax[:, np.maximum(i-1, 0):np.minimum(i+1,n)])
# ----> 8     k = np.maximum(Rmax[:, np.maximum(i-1, 0):np.minimum(i+1,n)])
#       9     print (k)
#      10     #maxSpace(:,:,max(i-1,1):min(i+1,n)),[],3)
#
# ValueError: invalid number of arguments

# %%
np.minimum(-1, 4)
# Out:
# -1

# %%
# Perform non-maximum suppression in scale space
max_space = np.zeros((h, w, n))
suppression_size = 3
for i in range(n): 
    R = scale_space[:, :, i]
    Rmax = generic_filter(R, np.max, footprint=np.ones((3, 3)) )
    max_space[:, :, i] = Rmax
#     Rmax[Rmax != R] = 0 #Suppression of Non-max
#     #v = Rmax[Rmax != 0]
#     #print (np.nonzero(Rmax))
#     #max_space[:, :, i] = np.nonzero(Rmax)
#     x, y = np.nonzero(Rmax)

# %%
for i in range(n):
    x = (max_space[:, :, i] * max_space[:, :, i])
    print (x)
# Out:
# [[  2.85454708e-09   2.85454708e-09   2.07981643e-09 ...,   8.55605157e-10
#     8.66817945e-11   8.66817945e-11]
#  [  1.17613774e-08   1.17613774e-08   2.07981643e-09 ...,   5.87205819e-09
#     1.55986831e-09   8.66817945e-11]
#  [  1.63588022e-08   1.63588022e-08   1.52969586e-09 ...,   1.61848125e-08
#     3.98990042e-09   8.15031712e-11]
#  ...,
#  [  5.14729502e-10   5.14729502e-10   4.99993519e-10 ...,   1.03623936e-07
#     8.22708949e-08   8.22708949e-08]
#  [  5.14729502e-10   5.14729502e-10   4.99993519e-10 ...,   7.33049522e-08
#     2.96238773e-08   2.96238773e-08]
#  [  1.24009146e-10   1.24009146e-10   8.51750464e-11 ...,   4.45692929e-08
#     1.91863682e-08   5.82796075e-09]]
# [[  1.52148823e-09   1.52148823e-09   6.12817723e-10 ...,   3.21226489e-10
#     4.21369963e-11   3.06430446e-12]
#  [  1.69295392e-09   1.69295392e-09   6.12817723e-10 ...,   1.19538663e-09
#     2.37930932e-10   5.30781670e-12]
#  [  1.69295392e-09   1.69295392e-09   5.07021833e-10 ...,   2.25248511e-09
#     4.51196197e-10   1.12727987e-11]
#  ...,
#  [  1.84874489e-11   1.84874489e-11   1.84874489e-11 ...,   2.40433025e-08
#     2.55205346e-09   2.13452317e-09]
#  [  1.84874489e-11   1.84874489e-11   1.84874489e-11 ...,   1.60894106e-08
#     2.78759247e-09   4.17967120e-10]
#  [  7.47431943e-12   7.47431943e-12   7.26988250e-12 ...,   1.08486397e-08
#     2.78759247e-09   5.12286610e-11]]
# [[  2.49155512e-10   2.49155512e-10   1.04122979e-10 ...,   9.88272744e-11
# [[  2.05773709e-16   2.05773709e-16   2.05219809e-16 ...,   1.15924949e-18
#     1.16481241e-18   1.16481241e-18]
#  [  2.05773709e-16   2.05773709e-16   2.05219809e-16 ...,   1.16943042e-18
#     1.17502825e-18   1.17502825e-18]
#  [  2.05578715e-16   2.05578715e-16   2.05025249e-16 ...,   1.18478236e-18
#     1.19043263e-18   1.19043263e-18]
#  ...,
#  [  8.33048411e-18   8.33048411e-18   8.27552801e-18 ...,   2.02185762e-19
#     2.02150523e-19   2.02117108e-19]
#  [  8.34378265e-18   8.34378265e-18   8.28875920e-18 ...,   2.00039142e-19
#     2.00004595e-19   1.99971700e-19]
#  [  8.34378265e-18   8.34378265e-18   8.28875920e-18 ...,   1.98617933e-19
#     1.98583844e-19   1.98551294e-19]]
# [[  3.74122442e-18   3.74122442e-18   3.73091142e-18 ...,   1.14500251e-18
#     1.14681502e-18   1.14681502e-18]
#  [  3.74122442e-18   3.74122442e-18   3.73091142e-18 ...,   1.14804695e-18
#     1.14986354e-18   1.14986354e-18]
#  [  3.73600518e-18   3.73600518e-18   3.72570402e-18 ...,   1.15261483e-18
#     1.15443753e-18   1.15443753e-18]
#  ...,
#  [  2.90683805e-21   2.97544533e-21   3.08100782e-21 ...,   1.38699706e-18
#     1.38652184e-18   1.38616855e-18]
#  [  2.90760670e-21   2.97624207e-21   3.08184803e-21 ...,   1.38574679e-18
#     1.38526824e-18   1.38491275e-18]
#  [  2.90760670e-21   2.97624207e-21   3.08184803e-21 ...,   1.38490792e-18
#     1.38442716e-18   1.38407022e-18]]

# %%
# non-maximum suppression between scales and threshold
for i in range(n):
    max_space[:, :, i] = np.amax(max_space[:, :, i], 0)

# %%
x, y, radius, value = [], [], [], []
for i in range(n):
    rows, cols = np.where(np.matmul(max_space[:, :, i], max_space[:, :, i].T) > threshold)

# %%
drawBlobs(im, max_space, threshold)

# %%
max_space[:, :, 0].shape
# Out:
# (356, 493)

# %%
maxSpace(:,:,i) = max(maxSpace(:,:,max(i-1,1):min(i+1,n)),[],3)

# %%
# non-maxima suppression within 3x3 windows
    Rmax = gf(R, np.max, footprint=np.ones((3, 3)))
    Rmax[Rmax != R] = 0  # suppress non-max
    v = Rmax[Rmax != 0]
    x, y = np.nonzero(Rmax)
# Out:
# array([[  3.00010104e-05,   1.91120724e-05,   6.15126318e-06, ...,
#           3.50042923e-06,   2.18711899e-07,   1.98733843e-07],
#        [  2.96381129e-05,   1.75246366e-05,   4.38404292e-06, ...,
#           6.42097676e-06,   9.67749442e-07,   1.52987422e-09],
#        [  2.88187152e-05,   1.54309292e-05,   2.57328209e-06, ...,
#           1.13941916e-05,   2.53296274e-06,   1.62395460e-07],
#        ...,
#        [  2.44299134e-06,   2.35340722e-06,   1.96510416e-06, ...,
#           3.48385915e-05,   1.41263395e-06,   4.82392070e-06],
#        [  2.18100701e-06,   2.03986546e-06,   1.62240402e-06, ...,
#           3.61568473e-05,   4.64964682e-06,   5.09687941e-07],
#        [  1.42469688e-06,   1.29565155e-06,   9.49885150e-07, ...,
#           3.70997279e-05,   7.51269387e-06,   3.00824479e-08]])
