# %%
import numpy as np
import utils
from utils import loadmat
from extractDigitFeatures import extractDigitFeatures
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, Conv3D, Flatten, MaxPool2D, AveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.python.keras import metrics
from keras import regularizers
from keras.constraints import unit_norm
from sklearn.model_selection import StratifiedKFold
from keras.callbacks import EarlyStopping

# %%
def get_random_data(data1, data2, low, high, max_samples=100):
    N, H1, W1, C1 = data1.shape
    #_, N1 = data2.shape
    suff_data1 = np.zeros((max_samples, H1, W1, C1))
    suff_data2 = np.zeros((max_samples,))
    shuffles = np.random.randint(low, high+1, max_samples)
    for idx in range(shuffles.shape[0]):
        suff_data1[idx] = data1[idx, :, :, :]
        suff_data2[idx] = data2[idx]
    return suff_data1, suff_data2

def reformat(x):
    new_x = np.zeros((x.shape[2], x.shape[0], x.shape[1]))
    for i in range(x.shape[2]):
        new_x[i, :] = x[:, :, i]
    return new_x[:, :, :, np.newaxis]

def return_datasets(filename):
    data = utils.loadmat('../data/{}'.format(filename))
    trainSet, testSet, valSet = 1, 2, 3
    
    x_train = reformat(data['x'][:, :, data['set']==trainSet ])
    y_train = (data['y'][data['set']==trainSet])
    x_val = reformat(data['x'][:, :, data['set']==valSet])
    y_val = (data['y'][data['set']==valSet])
    x_test = reformat(data['x'][:, :, data['set']==testSet])
    y_test = (data['y'][data['set']==testSet])
    
    x_train, y_train = get_random_data(x_train, y_train, 0, x_train.shape[0], x_train.shape[0])
    x_val, y_val = get_random_data(x_val, y_val, 0, x_val.shape[0], x_val.shape[0])
    x_test, y_test = get_random_data(x_test, y_test, 0, x_test.shape[0], x_test.shape[0])
    
    #print (x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape)
    

    #return (X, Y, x_test, y_test)
    return (x_train, y_train, x_val, y_val, x_test, y_test)

# %%
def extract_model(activation_func = 'relu'):
    model = Sequential()
    kernel_size=(5)
    stride_size = (2)

    model.add(Conv2D(32, kernel_size=kernel_size, strides=stride_size, activation=activation_func, padding='same', input_shape=(28, 28, 1)))
    model.add(MaxPool2D(2, 2))
    model.add(BatchNormalization())
    model.add(Conv2D(32, kernel_size=kernel_size, strides=stride_size, activation=activation_func, padding='same'))
    model.add(MaxPool2D(2, 2))
    model.add(BatchNormalization())

    model.add(Conv2D(64, kernel_size=kernel_size, strides=stride_size, activation=activation_func, padding='same'))
    #model.add(MaxPool2D(2, 2))
    model.add(BatchNormalization())
    
    model.add(Conv2D(64, kernel_size=kernel_size, strides=stride_size, activation=activation_func, padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(96, kernel_size=kernel_size, strides=stride_size, activation=activation_func, padding='same'))
    model.add(BatchNormalization())


    model.add(Flatten())
    model.add(Dense(256, activation=activation_func)) 
    model.add(Dense(10, activation='softmax'))
    
    return model

# %%
file = 'digits-jitter.mat'
x_train, y_train, x_val, y_val, x_test, y_test = return_datasets(file)
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
best_model, best_accuracy = -1, -1

for train, test in kfold.split(x_train, y_train):
    curr_x_train, curr_y_train = x_train[train], to_categorical(y_train[train], num_classes=10)
    curr_x_val, curr_y_val = x_train[train], to_categorical(y_train[train], num_classes=10)
    
    model = extract_model()
    if file == 'digits-scaled.mat':
        model = model_extractor('selu')

    model.compile(loss="categorical_crossentropy", optimizer='Adam', validation_data=(curr_x_val, curr_y_val), metrics=["accuracy"])
    model.fit(curr_x_train, curr_y_train, epochs=MAX_EPOCHS, batch_size=MAX_BATCH_SIZE, verbose=1)
    accuracy = model.evaluate(x_val, to_categorical(y_val, num_classes=10), verbose=0)[1]
    print ("Accuracy = {}".format(accuracy))
    if accuracy > best_accuracy:
        best_accuracy, best_model = accuracy, model

print ("Test Set Accuracy for {} = {}".format(file, best_model.evaluate(x_test, to_categorical(y_test, num_classes=10), verbose=0)))
# Out:
# Train on 900 samples
# Epoch 1/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 2.2646 - accuracy: 0.2033
# Epoch 2/20
# 900/900 [==============================] - 6s 7ms/sample - loss: 1.9465 - accuracy: 0.2800
# Epoch 3/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 1.7424 - accuracy: 0.3656
# Epoch 4/20
# 900/900 [==============================] - 1s 829us/sample - loss: 1.4501 - accuracy: 0.4700
# Epoch 5/20
# 900/900 [==============================] - 1s 825us/sample - loss: 1.2834 - accuracy: 0.5700
# Epoch 6/20
# 900/900 [==============================] - 1s 987us/sample - loss: 1.0208 - accuracy: 0.6478
# Epoch 7/20
# 900/900 [==============================] - 1s 866us/sample - loss: 0.9423 - accuracy: 0.6789
# Epoch 8/20
# 900/900 [==============================] - 1s 918us/sample - loss: 0.8991 - accuracy: 0.6956
# Epoch 9/20
# 900/900 [==============================] - 1s 941us/sample - loss: 0.7069 - accuracy: 0.7611
# Epoch 10/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.6749 - accuracy: 0.7756
# Epoch 11/20
# 900/900 [==============================] - 16s 17ms/sample - loss: 0.5783 - accuracy: 0.7967
# Epoch 12/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 0.4941 - accuracy: 0.8222
# Epoch 13/20
# 900/900 [==============================] - 1s 823us/sample - loss: 0.4359 - accuracy: 0.8589
# Epoch 14/20
# 900/900 [==============================] - 1s 837us/sample - loss: 0.3984 - accuracy: 0.8578
# Epoch 15/20
# 900/900 [==============================] - 1s 827us/sample - loss: 0.4094 - accuracy: 0.8667
# Epoch 16/20
# 900/900 [==============================] - 1s 830us/sample - loss: 0.3858 - accuracy: 0.8733
# Epoch 17/20
# 900/900 [==============================] - 1s 818us/sample - loss: 0.3340 - accuracy: 0.8889
# Epoch 18/20
# 900/900 [==============================] - 1s 833us/sample - loss: 0.3786 - accuracy: 0.8767
# Epoch 19/20
# 900/900 [==============================] - 1s 820us/sample - loss: 0.3572 - accuracy: 0.8656
# Epoch 20/20
# 900/900 [==============================] - 1s 821us/sample - loss: 0.2481 - accuracy: 0.9211
# Accuracy = 0.621999979019165
# Train on 900 samples
# Epoch 1/20
# 900/900 [==============================] - 2s 3ms/sample - loss: 2.2891 - accuracy: 0.1822
# Epoch 2/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 1.9351 - accuracy: 0.3022
# Epoch 3/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 1.6844 - accuracy: 0.3956
# Epoch 4/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 1.3772 - accuracy: 0.5244
# Epoch 5/20
# 900/900 [==============================] - 1s 974us/sample - loss: 1.1718 - accuracy: 0.5900
# Epoch 6/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 1.0609 - accuracy: 0.6322
# Epoch 7/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 0.8284 - accuracy: 0.7289
# Epoch 8/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 0.7776 - accuracy: 0.7211
# Epoch 9/20
# 900/900 [==============================] - 10s 12ms/sample - loss: 0.5925 - accuracy: 0.8078
# Epoch 10/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 0.5632 - accuracy: 0.8211
# Epoch 11/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 0.6009 - accuracy: 0.7878
# Epoch 12/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 0.4850 - accuracy: 0.8356
# Epoch 13/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 0.4149 - accuracy: 0.8711
# Epoch 14/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 0.4525 - accuracy: 0.8344
# Epoch 15/20
# 900/900 [==============================] - 1s 958us/sample - loss: 0.4485 - accuracy: 0.8411
# Epoch 16/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 0.3468 - accuracy: 0.8756
# Epoch 17/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 0.3352 - accuracy: 0.9022
# Epoch 18/20
# 900/900 [==============================] - 1s 995us/sample - loss: 0.3083 - accuracy: 0.8967
# Epoch 19/20
# 900/900 [==============================] - 1s 971us/sample - loss: 0.3575 - accuracy: 0.8744
# Epoch 20/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 0.2841 - accuracy: 0.9044
# Accuracy = 0.5899999737739563
# Train on 900 samples
# Epoch 1/20
# 900/900 [==============================] - 3s 3ms/sample - loss: 2.2844 - accuracy: 0.1767
# Epoch 2/20
# 900/900 [==============================] - 1s 780us/sample - loss: 1.9281 - accuracy: 0.3033
# Epoch 3/20
# 900/900 [==============================] - 1s 944us/sample - loss: 1.6687 - accuracy: 0.3933
# Epoch 4/20
# 900/900 [==============================] - 1s 760us/sample - loss: 1.3958 - accuracy: 0.4933
# Epoch 5/20
# 900/900 [==============================] - 1s 772us/sample - loss: 1.1772 - accuracy: 0.5833
# Epoch 6/20
# 900/900 [==============================] - 1s 785us/sample - loss: 1.1083 - accuracy: 0.5889
# Epoch 7/20
# 900/900 [==============================] - 1s 789us/sample - loss: 0.9162 - accuracy: 0.6889
# Epoch 8/20
# 900/900 [==============================] - 1s 824us/sample - loss: 0.7733 - accuracy: 0.7278
# Epoch 9/20
# 900/900 [==============================] - 1s 782us/sample - loss: 0.7113 - accuracy: 0.7589
# Epoch 10/20
# 900/900 [==============================] - 1s 776us/sample - loss: 0.6949 - accuracy: 0.7722
# Epoch 11/20
# 900/900 [==============================] - 1s 895us/sample - loss: 0.5942 - accuracy: 0.8000
# Epoch 12/20
# 900/900 [==============================] - 2s 3ms/sample - loss: 0.5428 - accuracy: 0.8122
# Epoch 13/20
# 900/900 [==============================] - 2s 3ms/sample - loss: 0.5450 - accuracy: 0.8211
# Epoch 14/20
# 900/900 [==============================] - 1s 933us/sample - loss: 0.5320 - accuracy: 0.8178
# Epoch 15/20
# 900/900 [==============================] - 1s 953us/sample - loss: 0.2909 - accuracy: 0.8967
# Epoch 16/20
# 900/900 [==============================] - 1s 952us/sample - loss: 0.2952 - accuracy: 0.9089
# Epoch 17/20
# 900/900 [==============================] - 1s 965us/sample - loss: 0.3795 - accuracy: 0.8822
# Epoch 18/20
# 900/900 [==============================] - 1s 915us/sample - loss: 0.4093 - accuracy: 0.8622
# Epoch 19/20
# 900/900 [==============================] - 1s 984us/sample - loss: 0.3395 - accuracy: 0.8911
# Epoch 20/20
# 900/900 [==============================] - 1s 931us/sample - loss: 0.2726 - accuracy: 0.9078
# Accuracy = 0.5400000214576721
# Train on 900 samples
# Epoch 1/20
# 900/900 [==============================] - 4s 4ms/sample - loss: 2.3320 - accuracy: 0.1578
# Epoch 2/20
# 900/900 [==============================] - 3s 4ms/sample - loss: 1.9752 - accuracy: 0.3000
# Epoch 3/20
# 900/900 [==============================] - 1s 848us/sample - loss: 1.7013 - accuracy: 0.4044
# Epoch 4/20
# 900/900 [==============================] - 1s 883us/sample - loss: 1.4371 - accuracy: 0.5100
# Epoch 5/20
# 900/900 [==============================] - 3s 3ms/sample - loss: 1.1820 - accuracy: 0.6033
# Epoch 6/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 1.0700 - accuracy: 0.6333
# Epoch 7/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 0.9363 - accuracy: 0.6678
# Epoch 8/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 0.7669 - accuracy: 0.7400
# Epoch 9/20
# 900/900 [==============================] - 1s 993us/sample - loss: 0.6241 - accuracy: 0.7822
# Epoch 10/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 0.6562 - accuracy: 0.7767
# Epoch 11/20
# 900/900 [==============================] - 1s 1ms/sample - loss: 0.5760 - accuracy: 0.8000
# Epoch 12/20
# 900/900 [==============================] - 8s 9ms/sample - loss: 0.5151 - accuracy: 0.8367
# Epoch 13/20
# 900/900 [==============================] - 244s 271ms/sample - loss: 0.4332 - accuracy: 0.8578
# Epoch 14/20
# 900/900 [==============================] - 2s 3ms/sample - loss: 0.3923 - accuracy: 0.8789
# Epoch 15/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.3002 - accuracy: 0.9011
# Epoch 16/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.4686 - accuracy: 0.8300
# Epoch 17/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.3669 - accuracy: 0.8744
# Epoch 18/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.3262 - accuracy: 0.8911
# Epoch 19/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.2940 - accuracy: 0.9078
# Epoch 20/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.3192 - accuracy: 0.9011
# Accuracy = 0.4659999907016754
# Train on 900 samples
# Epoch 1/20
# 900/900 [==============================] - 283s 314ms/sample - loss: 2.2795 - accuracy: 0.1867
# Epoch 2/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 1.9644 - accuracy: 0.3000
# Epoch 3/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 1.6517 - accuracy: 0.4178
# Epoch 4/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 1.4275 - accuracy: 0.5156
# Epoch 5/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 1.2084 - accuracy: 0.5767
# Epoch 6/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 1.0376 - accuracy: 0.6389
# Epoch 7/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.9056 - accuracy: 0.6878
# Epoch 8/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.7199 - accuracy: 0.7578
# Epoch 9/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.6679 - accuracy: 0.7767
# Epoch 10/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.5737 - accuracy: 0.7989
# Epoch 11/20
# 900/900 [==============================] - 223s 248ms/sample - loss: 0.6306 - accuracy: 0.8011
# Epoch 12/20
# 900/900 [==============================] - 59s 66ms/sample - loss: 0.4896 - accuracy: 0.8367
# Epoch 13/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.4196 - accuracy: 0.8589
# Epoch 14/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.3659 - accuracy: 0.8889
# Epoch 15/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.4214 - accuracy: 0.8533
# Epoch 16/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.3861 - accuracy: 0.8833
# Epoch 17/20
# 900/900 [==============================] - 3s 3ms/sample - loss: 0.3665 - accuracy: 0.8789
# Epoch 18/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.2619 - accuracy: 0.9178
# Epoch 19/20
# 900/900 [==============================] - 3s 3ms/sample - loss: 0.3238 - accuracy: 0.8833
# Epoch 20/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.3166 - accuracy: 0.8944
# Accuracy = 0.6179999709129333
# Train on 900 samples
# Epoch 1/20
# 900/900 [==============================] - 281s 312ms/sample - loss: 2.3015 - accuracy: 0.1867
# Epoch 2/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 1.9825 - accuracy: 0.2733
# Epoch 3/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 1.7269 - accuracy: 0.3789
# Epoch 4/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 1.4368 - accuracy: 0.4933
# Epoch 5/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 1.1793 - accuracy: 0.5933
# Epoch 6/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 1.0127 - accuracy: 0.6456
# Epoch 7/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.8557 - accuracy: 0.6900
# Epoch 8/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.7509 - accuracy: 0.7400
# Epoch 9/20
# 900/900 [==============================] - 2s 2ms/sample - loss: 0.6584 - accuracy: 0.7844
# Epoch 10/20
# 900/900 [==============================] - 3s 3ms/sample - loss: 0.5703 - accuracy: 0.8033
# Epoch 11/20
# 900/900 [==============================] - 4s 5ms/sample - loss: 0.6042 - accuracy: 0.7967
# Epoch 12/20
# 530/900 [================>.............] - ETA: 2:59 - loss: 0.5666 - accuracy: 0.8192
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-eb9873f8f8ed> in <module>
#      13
#      14     model.compile(loss="categorical_crossentropy", optimizer='Adam', validation_data=(curr_x_val, curr_y_val), metrics=["accuracy"])
# ---> 15     model.fit(curr_x_train, curr_y_train, epochs=MAX_EPOCHS, batch_size=MAX_BATCH_SIZE, verbose=1)
#      16     accuracy = model.evaluate(x_val, to_categorical(y_val, num_classes=10), verbose=0)[1]
#      17     print ("Accuracy = {}".format(accuracy))
#
# ~/anaconda3/envs/cs682/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# ~/anaconda3/envs/cs682/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     322                 mode=ModeKeys.TRAIN,
#     323                 training_context=training_context,
# --> 324                 total_epochs=epochs)
#     325             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     326
#
# ~/anaconda3/envs/cs682/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
# --> 123         batch_outs = execution_function(iterator)
#     124       except (StopIteration, errors.OutOfRangeError):
#     125         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~/anaconda3/envs/cs682/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      84     # `numpy` translates Tensors to values in Eager mode.
#      85     return nest.map_structure(_non_none_constant_value,
# ---> 86                               distributed_function(input_fn))
#      87
#      88   return execution_function
#
# ~/anaconda3/envs/cs682/lib/python3.6/site-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     455
#     456     tracing_count = self._get_tracing_count()
# --> 457     result = self._call(*args, **kwds)
#     458     if tracing_count == self._get_tracing_count():
#     459       self._call_counter.called_without_tracing()
#
# ~/anaconda3/envs/cs682/lib/python3.6/site-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     485       # In this case we have created variables on the first call, so we run the
#     486       # defunned version which is guaranteed to never create variables.
# --> 487       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     488     elif self._stateful_fn is not None:
#     489       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/cs682/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1821     """Calls a graph function specialized to the inputs."""
#    1822     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 1823     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    1824
#    1825   @property
#
# ~/anaconda3/envs/cs682/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1139          if isinstance(t, (ops.Tensor,
#    1140                            resource_variable_ops.BaseResourceVariable))),
# -> 1141         self.captured_inputs)
#    1142
#    1143   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/envs/cs682/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# ~/anaconda3/envs/cs682/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/cs682/lib/python3.6/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
# MAX_EPOCHS = 20
# MAX_BATCH_SIZE = 10

# files = ['digits-normal.mat', ] 
# for file in files:
#     x_train, y_train, x_val, y_val, x_test, y_test = return_datasets(file)

#     model = extract_model('relu')
#     model.compile(loss="categorical_crossentropy", optimizer='Adam', validation_data=(x_val, y_val), metrics=["accuracy"])
#     model.fit(x_train, y_train, epochs=MAX_EPOCHS, batch_size=MAX_BATCH_SIZE,  verbose=1)
#     accuracy = model.evaluate(x_test, y_test, verbose=0)[1]
#     print ("Accuracy = {}".format(accuracy))
